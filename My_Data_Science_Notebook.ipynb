# %% [markdown]
# # My Data Science Notebook

# %% [markdown]
# # My Data Science Notebook

# %% [markdown]
# This notebook introduces basic concepts and tools in Data Science.

# %% [markdown]
# ## Data Science Languages
# - Python
# - R
# - SQL
# - Julia

# %% [markdown]
# ## Data Science Libraries
# - Pandas
# - NumPy
# - Matplotlib
# - ggplot2
# - Scikit-learn

# %% [markdown]
# ## Data Science Tools
#
# | Tool        | Purpose                  |
# |------------|------------------------|
# | JupyterLite | Interactive coding      |
# | RStudio    | R programming           |
# | GitHub     | Version control         |
# | Tableau    | Data visualization      |

# %% [markdown]
# ## Arithmetic Expression Examples
# The following code cells demonstrate simple arithmetic operations in Python.

# %%
# Multiply and add numbers example
result = 5 * 3 + 10
result
# Out:
# 25

# %%
# Convert minutes to hours
minutes = 90
hours = minutes / 60
hours
# Out:
# 1.5

# %% [markdown]
# ## Objectives
# - Learn basic Python arithmetic operations
# - Convert time units
# - Explore data science tools and libraries

# %% [markdown]
# **Author:** Rosa
